# %%
# %pip install matplotlib numpy
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Requirement already satisfied: matplotlib in d:\data_analyst_bootcamp\python\venv\lib\site-packages (3.10.8)
# Requirement already satisfied: numpy in d:\data_analyst_bootcamp\python\venv\lib\site-packages (2.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\data_analyst_bootcamp\python\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\data_analyst_bootcamp\python\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\data_analyst_bootcamp\python\venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\data_analyst_bootcamp\python\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\data_analyst_bootcamp\python\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\data_analyst_bootcamp\python\venv\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in d:\data_analyst_bootcamp\python\venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\data_analyst_bootcamp\python\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\data_analyst_bootcamp\python\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import expense_tracker 
import csv

import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 import expense_tracker
#       2 import csv
# ----> 3 import expense_file_path
#       4 import os
#
# ModuleNotFoundError: No module named 'expense_file_path'

# %%
import pandas as pd
import expense

# %%
def visualize_expenses_by_category():
    # Read the expenses from the CSV file
    df = pd.read_csv("expense.csv")
    category_spend = df.groupby("category")["amount"].sum()

    plt.figure()
    plt.pie(category_spend, labels=category_spend.index, autopct="%1.1f%%")
    plt.title("Spending by Category")
    plt.show()

# %%
visualize_expenses_by_category()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 visualize_expenses_by_category()
#
# Cell In[31], line 4, in visualize_expenses_by_category()
#       1 def visualize_expenses_by_category():
#       2     # Read the expenses from the CSV file
#       3     df = pd.read_csv("expense.csv")
# ----> 4     category_spend = df.groupby("category")["amount"].sum()
#       6     plt.figure()
#       7     plt.pie(category_spend, labels=category_spend.index, autopct="%1.1f%%")
#
# File d:\DATA_ANALYST_BOOTCAMP\PYTHON\venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File d:\DATA_ANALYST_BOOTCAMP\PYTHON\venv\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
#   10815     raise TypeError("You have to supply one of 'by' and 'level'")
# > 10817 return DataFrameGroupBy(
#   10818     obj=self,
#   10819     keys=by,
#   10820     level=level,
#   10821     as_index=as_index,
#   10822     sort=sort,
#   10823     group_keys=group_keys,
#   10824     observed=observed,
#   10825     dropna=dropna,
#   10826 )
#
# File d:\DATA_ANALYST_BOOTCAMP\PYTHON\venv\Lib\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File d:\DATA_ANALYST_BOOTCAMP\PYTHON\venv\Lib\site-packages\pandas\core\groupby\grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'category'

# %%
print(df.columns)
# Out:
# Index(['PIZZA', 'FOOD 🍔', '250.0', '2026-02-14 12:49:39'], dtype='str')
